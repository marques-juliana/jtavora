# %%
import pandas as pd
import numpy as np
import nltk
import ast
nltk.download('stopwords') 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('Juarez_words_full.csv')
df_words = df[['Palavras']]
df_words['Palavras'] = df_words['Palavras'].apply(ast.literal_eval)
# Out:
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
stop_words = set(stopwords.words('portuguese'))

def retirar_stop_words(x):
    words = [i for i in x if i not in stop_words]
    return words

# %%
df_words['Palavras'] = df_words['Palavras'].apply(retirar_stop_words) 

df_words['Palavras'] = df_words['Palavras'].apply(lambda x: ' '.join(word for word in x))
# Out:
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
count_vectorizer = CountVectorizer()
count_data = count_vectorizer.fit_transform(df_words['Palavras'])

# %%
words = count_vectorizer.get_feature_names()
total_counts = np.zeros(len(words))
for t in count_data:
    total_counts+=t.toarray()[0]

count_dict = (zip(words, total_counts))
count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)

# %%
df = pd.DataFrame(count_dict)
df.columns = ['Palavra','Quantidade']

# %%
df[df['Quantidade'] == 1].to_excel('Palavras_quantidade_1.xlsx')

# %%
df[df['Quantidade'] == 1]
# Out:
#               Palavra  Quantidade
# 13642         abacate         1.0
# 13643          abadar         1.0
# 13644          abadia         1.0
# 13645           abafa         1.0
# 13646        abafadas         1.0
# 13647         abafado         1.0
# 13648      abalizados         1.0
# 13649           abano         1.0
# 13650         abarcar         1.0
# 13651     abarrotados         1.0
# 13652       abastadas         1.0
# 13653  abastardamento         1.0
# 13654     abastecedor         1.0
# 13655      abastecida         1.0
# 13656      abastecido         1.0
# 13657     abastecidos         1.0
# 13658           abate         1.0
# 13659        abatedor         1.0
# 13660         abatida         1.0
# 13661        abatidas         1.0
# 13662         abdalla         1.0
# 13663       abeberado         1.0
# 13664       aberrante         1.0
# 13665      aberrantes         1.0
# 13666           abeto         1.0
# 13667            abio         1.0
# 13668         abismar         1.0
# 13669         abjecto         1.0
# 13670         abjetas         1.0
# 13671          abjeto         1.0
# ...               ...         ...
# 19075          watson         1.0
# 19076            watt         1.0
# 19077         werneck         1.0
# 19078      wilsoniano         1.0
# 19079            wind         1.0
# 19080        wladimir         1.0
# 19081            xaca         1.0
# 19082            xaco         1.0
# 19083            xais         1.0
# 19084           xaxim         1.0
# 19085       xenofobia         1.0
# 19086           xeque         1.0
# 19087          xicaca         1.0
# 19088            xuxo         1.0
# 19089            yves         1.0
# 19090         zabumba         1.0
# 19091          zagalo         1.0
# 19092           zaira         1.0
# 19093            zama         1.0
# 19094            zana         1.0
# 19095           zanga         1.0
# 19096          zangar         1.0
# 19097         zelosos         1.0
# 19098         zenital         1.0
# 19099          zenith         1.0
# 19100            zeus         1.0
# 19101           zilda         1.0
# 19102      zoneamento         1.0
# 19103             zoo         1.0
# 19104          zurzir         1.0
#
# [5463 rows x 2 columns]
