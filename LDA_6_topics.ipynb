# %%
import pandas as pd
import nltk
import ast
nltk.download('stopwords') 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
from pyLDAvis import sklearn as sklearn_lda
import re
import os
import numpy as np
from gensim import models, corpora
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
from nltk import tokenize
from tqdm.notebook import tqdm
import pyLDAvis
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('Juarez_words_full.csv')
df_words = df[['Palavras']]
df_words['Palavras'] = df_words['Palavras'].apply(ast.literal_eval)


stop_words = stopwords.words('portuguese')
stop_words_manual = ['to','pt','sobre','ca','si','al','ra','ainda','ai','so','ta','ae','fl','in','oa','fi','at','co','li','ti','qualquer','ha','dr','sa','ter','be','tal','ar','sob','onde','es','ma','of','ri','re','ir','assim','la','sempre','desde','cl','jl','is','mo','am','ac','it','oe','an','st','ro','or','en','vez','on','pa','io','dc','lo','deste','alguns','fa','pe','mi','lu','mm','va','pis','ua','af','agora','ce','le','il','he','vossa','via','pi','ne','des','ali','pr','om','quais','nesse','alguma','el','cr','az','aj','aue','ei','au','demais','nessa','av','qua','ul','ho','et','po','vo','perante','ve','pu','di','ap','tr','ie','su','ui','un','ad','per','nt','logo','go','ji','du','bo','fo','er','jo','mu']

stop_words = set(stop_words + stop_words_manual)
# Out:
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def retirar_stop_words(x):
    words = [i for i in x if i not in stop_words]
    return words

# %%
df_words['Palavras'] = df_words['Palavras'].apply(retirar_stop_words) 

df_words['Palavras'] = df_words['Palavras'].apply(lambda x: ' '.join(word for word in x))
# Out:
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data = []
for index, row in df_words.iterrows():
    data.append(row['Palavras'])

data = [i for i in data if i != '']    
#data = ' '.join(array)

# %%
def bigramas(words):
 
    bigrams = []
 
    for i in range(0, len(words)):
        if (i == len(words)-1):
            break
        else:
            bigrama_obs = words[i] + '_' + words[i+1]
            bigrams.append(bigrama_obs)
 
    return bigrams

def trigramas(words):
 
    trigrams = []
 
    for i in range(0, len(words)):
        if (i == len(words)-2):
            break
        else:
            try:
                trigrama_obs = words[i] + '_' + words[i+1] + '_' + words[i+2]
                trigrams.append(trigrama_obs)
            except:
                pass
    return trigrams

# %%
tokenized_data = []
texto2 = []
total_unigramas = []
total_bigramas = []
total_trigramas = []

for texto in tqdm(data):
    
    xtexto = word_tokenize(texto)
#CRIAR O UNIGRAMA, BIGRAMAS, TRIGRAMAS
    unigramas = xtexto
    xbigramas = bigramas(xtexto)
    xtrigramas = trigramas(xtexto)
    xunigramas = unigramas + xbigramas + xtrigramas
    
    tokenized_data.append(xunigramas)
    texto2 = texto2 + xunigramas

#CRIAR OPÇÃO PARA MOSTRAR A FREQUENCIA SOMENTE DE UNIGRAMA , BIGRAMAS E TRIGRAMAS
    total_unigramas = total_unigramas + unigramas
    total_bigramas = total_bigramas + xbigramas
    total_trigramas = total_trigramas + xtrigramas
    
xfrequencia = texto2
# Out:
# HBox(children=(IntProgress(value=0, max=23078), HTML(value='')))

# %%
#CRIAR DICIONÁRIO 
dictionary = corpora.Dictionary(tokenized_data)
 
#TRANSFORMAR A COLEÇÃO TEXTO COM ID
corpus = [dictionary.doc2bow(text) for text in tokenized_data]

# %%
print("=========================================== Modelo LDA: 06 TÓPICOS ==================================================\n")
num_topics = 6

chunksize = 300
passes = 15
iterations = 250
eval_every = None  # Don't evaluate model perplexity, takes too much time.
# %time model = models.LdaModel(corpus=corpus, id2word=dictionary, chunksize=chunksize, \
                       alpha='auto', eta='auto', \
                       iterations=iterations, num_topics=num_topics, \
                       passes=passes, eval_every=eval_every)

for idx in range(num_topics):
    print("Tópico %s: " % idx, model.print_topic(idx, 10))
# Out:
# =========================================== Modelo LDA: 06 TÓPICOS ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\gensim\models\ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     521             use_numpy = self.dispatcher is not None
#     522             start = time.time()
# --> 523             self.update(corpus, chunks_as_numpy=use_numpy)
#     524             self.add_lifecycle_event(
#     525                 "created",
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\gensim\models\ldamodel.py in update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#     992                         pass_, chunk_no * chunksize + len(chunk), lencorpus
#     993                     )
# --> 994                     gammat = self.do_estep(chunk, other)
#     995
#     996                     if self.optimize_alpha:
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\gensim\models\ldamodel.py in do_estep(self, chunk, state)
#     754         if state is None:
#     755             state = self.state
# --> 756         gamma, sstats = self.inference(chunk, collect_sstats=True)
#     757         state.sstats += sstats
#     758         state.numdocs += gamma.shape[0]  # avoids calling len(chunk) on a generator
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\gensim\models\ldamodel.py in inference(self, chunk, collect_sstats)
#     719                 # Contribution of document d to the expected sufficient
#     720                 # statistics for the M step.
# --> 721                 sstats[:, ids] += np.outer(expElogthetad.T, cts / phinorm)
#     722
#     723         if len(chunk) > 1:
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-fb2429097e0a> in <module>
#       9
#      10 for idx in range(num_topics):
# ---> 11     print("Tópico %s: " % idx, model.print_topic(idx, 10))
#
# NameError: name 'model' is not defined

# %%
total_bigramas
# Out:
# ['juarez_general',
#  'general_rio',
#  'rio_janeiro',
#  'gerente_barbosa',
#  'barbosa_affonso',
#  'affonso_banco',
#  'banco_queiroz',
#  'queiroz_arnaldo',
#  'arnaldo_neves',
#  'neves_ante',
#  'ante_horta',
#  'horta_moacyr',
#  'moacyr_almeida',
#  'almeida_coelho',
#  'coelho_lavrador',
#  'lavrador_antes',
#  'antes_francis',
#  'francis_julio',
#  'julio_corretor',
#  'corretor_lauro',
#  'lauro_edson',
#  'edson_prefeito',
#  'prefeito_jones',
#  'jones_paiva',
#  'paiva_companhia',
#  'companhia_vasconcellos',
#  'vasconcellos_prado',
#  'prado_medico',
#  'medico_waldemiro',
#  'waldemiro_western',
#  'western_santos',
#  'santos_jayme',
#  'jayme_pinto',
#  'pinto_pessoa',
#  'pessoa_soares',
#  'soares_costa',
#  'costa_advogado',
#  'departamento_telegrama',
#  'telegrama_indicar',
#  'indicar_hora',
#  'hora_y',
#  'y_recibo',
#  'recibo_entrega',
#  'entrega_receber',
#  'receber_cio',
#  'cio_apresentado',
#  'paris_riqueza',
#  'riqueza_madeira',
#  'madeira_artigo',
#  'artigo_extensa',
#  'extensa_primeiros',
#  'primeiros_terra',
#  'terra_mapa',
#  'mapa_alta',
#  'alta_diversas',
#  'diversas_faz',
#  'faz_portugal',
#  'portugal_despido',
#  'despido_dar',
#  'dar_principal',
#  'principal_vermelho',
#  'vermelho_causa',
#  'causa_chamado',
#  'chamado_catarina',
#  'catarina_franceses',
#  'franceses_grande',
#  'grande_parte',
#  'parte_porque',
#  'porque_troca',
#  'troca_servir',
#  'servir_habitantes',
#  'habitantes_atlas',
#  'atlas_iluminado',
#  'iluminado_cerca',
#  'cerca_corante',
#  'corante_documento',
#  'documento_executado',
#  'executado_rei',
#  'rei_apreciadas',
#  'apreciadas_uso',
#  'uso_brasil',
#  'brasil_grafo',
#  'grafo_atado',
#  'atado_homem',
#  'homem_dessa',
#  'dessa_jaime',
#  'jaime_miller',
#  'miller_aparece',
#  'aparece_pois',
#  'pois_ibirapitanga',
#  'ibirapitanga_dor',
#  'dor_primeiro',
#  'oj_documentos',
#  'documentos_pasta',
#  'pasta_destino',
#  'destino_guia',
#  'guia_data',
#  'documentos_pasta',
#  'pasta_destino',
#  'destino_guia',
#  'guia_data',
#  'grosso_ps',
#  'ps_julio',
#  'julio_sc',
#  'sc_realidade',
#  'realidade_sito',
#  'sito_t',
#  'y_sp',
#  'grosso_julio',
#  'julio_costa',
#  'costa_realidade',
#  'realidade_deve',
#  'vir_g',
#  'g_j',
#  'j_lopes',
#  'lopes_una',
#  'una_r',
#  'r_m',
#  'ser_salvo',
#  'salvo_viajar',
#  'viajar_cidade',
#  'cidade_ara',
#  'ara_conhecido',
#  'conhecido_delegacia',
#  'delegacia_desta',
#  'desta_liberdade',
#  'liberdade_delegado',
#  'conta_dessa',
#  'dessa_presente',
#  'presente_estrada',
#  'estrada_ferro',
#  'ferro_agente',
#  'agente_noroeste',
#  'conta_dessa',
#  'dessa_presente',
#  'presente_estrada',
#  'estrada_ferro',
#  'ferro_agente',
#  'agente_tio',
#  'tio_noroeste',
#  'estrada_ferro',
#  'ferro_gabinete',
#  'gabinete_noroeste',
#  'noroeste_brasil',
#  'schultz_conta',
#  'conta_toma',
#  'toma_senhor',
#  'senhor_abandonado',
#  'abandonado_conhecimento',
#  'conhecimento_respectivos',
#  'respectivos_desse',
#  'desse_unidade',
#  'unidade_citando',
#  'citando_norte',
#  'norte_continuar',
#  'continuar_aqui',
#  'aqui_ceu',
#  'ceu_grandes',
#  'grandes_doente',
#  'doente_fronteira',
#  'fronteira_comando',
#  'comando_impostos',
#  'impostos_porto',
#  'porto_octavio',
#  'octavio_victoria',
#  'victoria_c',
#  'c_garcia',
#  'garcia_hoje',
#  'hoje_dante',
#  'dante_quer',
#  'quer_secretario',
#  'secretario_inimigo',
#  'inimigo_dia',
#  'dia_toa',
#  'toa_seguros',
#  'seguros_setembro',
#  'setembro_sul',
#  'sul_quo',
#  'quo_todos',
#  'conhecimento_orestes',
#  'orestes_desorientado',
#  'desorientado_grandes',
#  'grandes_porto',
#  'porto_publico',
#  'publico_y',
#  'y_seguir',
#  'seguir_major',
#  'major_regular',
#  'regular_melhor',
#  'melhor_operando',
#  'operando_curso',
#  'curso_dia',
#  'dia_setembro',
#  'conhecimento_outro',
#  'outro_servir',
#  'servir_fim',
#  'fim_publico',
#  'publico_estrada',
#  'estrada_vai',
#  'vai_catanduva',
#  'catanduva_verificar',
#  'verificar_ponto',
#  'ponto_destino',
#  'destino_setembro',
#  'setembro_ito',
#  'ito_etc',
#  'etc_francisco',
#  'acontecimento_conhecimento',
#  'conhecimento_ante',
#  'ante_servir',
#  'servir_santa',
#  'santa_histeria',
#  'histeria_dar',
#  'dar_direitos',
#  'direitos_porto',
#  'porto_dias',
#  'dias_publico',
#  'publico_ordem',
#  'ordem_grande',
#  'grande_patriotas',
#  'patriotas_tomba',
#  'tomba_tristeza',
#  'tristeza_excluido',
#  'excluido_ente',
#  'ente_major',
#  'major_honra',
#  'honra_hoje',
#  'hoje_noticia',
#  'noticia_oito',
#  'oito_luto',
#  'luto_luminoso',
#  'luminoso_pesar',
#  'pesar_tudo',
#  'tudo_setembro',
#  'setembro_quo',
#  'quo_ria',
#  'muitos_tropa',
#  'tropa_especialmente',
#  'especialmente_quartel',
#  'quartel_artilharia',
#  'artilharia_almeida',
#  'almeida_alto',
#  'alto_destacada',
#  'destacada_neste',
#  'neste_ur',
#  'ur_externa',
#  'externa_porto',
#  'porto_moreira',
#  'moreira_general',
#  'general_distribuir',
#  'distribuir_porcas',
#  'porcas_prazer',
#  'prazer_agua',
#  'agua_baixo',
#  'baixo_frete',
#  'frete_major',
#  'major_grosso',
#  'grosso_tornado',
#  'tornado_credores',
#  'credores_hoje',
#  'hoje_estrada',
#  'estrada_chata',
#  'chata_vou',
#  'vou_setembro',
#  'setembro_elevado',
#  'elevado_continua',
#  'continua_juizo',
#  'juizo_tripas',
#  'tripas_etc',
#  'etc_bons',
#  'vanguarda_guerra',
#  'guerra_conhecimento',
#  'conhecimento_grupo',
#  'grupo_armas',
#  'armas_bens',
#  'bens_tino',
#  'tino_ordem',
#  'ordem_grande',
#  'grande_victoria',
#  'victoria_destacamento',
#  'destacamento_valentia',
#  'valentia_poste',
#  'poste_dia',
#  'conhecimento_contada',
#  'contada_outubro',
#  'outubro_porto',
#  'porto_porcas',
#  'porcas_mira',
#  'mira_frete',
#  'frete_seguido',
#  'seguido_valentia',
#  'valentia_data',
#  'data_apresentado',
#  'apresentado_toda',
#  'toda_dia',
#  'guerra_publicados',
#  'publicados_conhecimento',
#  'conhecimento_quartel',
#  'quartel_outubro',
#  'outubro_conforme',
#  'conforme_importantes',
#  'importantes_mister',
#  'mister_inclusive',
#  'inclusive_passo',
#  'passo_porto',
#  'porto_publico',
#  'publico_mesquita',
#  'mesquita_ordem',
#  'ordem_general',
#  'general_ficam',
#  'ficam_parte',
#  'parte_resolvido',
#  'resolvido_tomada',
#  'tomada_sol',
#  'sol_destacamento',
#  'destacamento_respectiva',
#  'respectiva_tomadas',
#  'tomadas_catanduva',
#  'catanduva_padilha',
#  'padilha_dia',
#  'dia_caso',
#  'caso_outros',
#  'outros_boletim',
#  'boletim_conselho',
#  'conselho_x',
#  'x_registrados',
#  'todo_servir',
#  'servir_outubro',
#  'outubro_passa',
#  'passa_completa',
#  'completa_piquete',
#  'piquete_porto',
#  'porto_introduzido',
#  'introduzido_general',
#  'general_lambert',
#  'lambert_ajudantes',
#  'ajudantes_oswaldo',
#  'oswaldo_autoridade',
#  'autoridade_pele',
#  'pele_adiante',
#  'adiante_cascavel',
#  'cascavel_guarda',
#  'guarda_mando',
#  'mando_salvo',
#  'salvo_secretario',
#  'secretario_duas',
#  'duas_transporte',
#  'transporte_continua',
#  'continua_indo',
#  'indo_algum',
#  'mandado_conhecimento',
#  'conhecimento_quartel',
#  'quartel_outubro',
#  'outubro_tao',
#  'tao_vi',
#  'vi_forcar',
#  'forcar_prestigio',
#  'prestigio_g',
#  'g_rodrigues',
#  'rodrigues_vem',
#  'vem_bem',
#  'bem_carvalho',
#  'carvalho_ram',
#  'ram_dia',
#  'dia_maior',
#  'maior_louvor',
#  'louvor_bons',
#  'rer_m',
#  'leopoldo_escalada',
#  'escalada_j',
#  'leopoldo_xp',
#  'xp_ju',
#  'ju_escalada',
#  'escalada_ju',
#  'y_escalada',
#  'leopoldo_y',
#  'y_escalada',
#  'estado_sol',
#  'sol_casa',
#  'casa_par',
#  'par_paulo',
#  'paulo_presidente',
#  'presidente_bi',
#  'bi_prudente',
#  'prudente_roupas',
#  'roupas_varejo',
#  'varejo_etc',
#  'etc_fita',
#  'boato_muitos',
#  'muitos_forca',
#  'forca_verdadeiro',
#  'verdadeiro_eis',
#  'eis_conhece',
#  'conhece_janeiro',
#  'janeiro_soldados',
#  'soldados_pedido',
#  'pedido_malar',
#  'malar_menos',
#  'menos_parte',
#  'parte_aprisionado',
#  'aprisionado_liberto',
#  'liberto_recado',
#  'recado_carlos',
#  'carlos_companhia',
#  'companhia_concentrar',
#  'concentrar_varias',
#  'varias_cousa',
#  'cousa_tenente',
#  'tenente_maioria',
#  'maioria_carvalho',
#  'carvalho_vermelhos',
#  'vermelhos_carro',
#  'carro_composta',
#  'composta_dois',
#  'dois_juan',
#  'juan_sabe',
#  'sabe_elemento',
#  'elemento_brasileiros',
#  'brasileiros_tio',
#  'tio_citada',
#  'citada_aqui',
#  'aqui_ceu',
#  'ceu_che',
#  'che_mil',
#  'mil_antes',
#  'antes_zona',
#  'zona_major',
#  'major_surpresa',
#  'surpresa_tonta',
#  'tonta_hoje',
#  'hoje_reserva',
#  'reserva_prado',
#  'prado_gente',
#  'gente_vinha',
#  'vinha_pessoas',
#  'pessoas_hospedado',
#  'hospedado_cada',
#  'cada_vinte',
#  'vinte_homens',
#  'homens_tropa',
#  'tropa_militar',
#  'militar_civil',
#  'civil_tracao',
#  'tracao_coronel',
#  'coronel_quartel',
#  'quartel_grossense',
#  'grossense_auxiliares',
#  'auxiliares_momento',
#  'momento_acima',
#  'acima_vinda',
#  'vinda_comando',
#  'comando_una',
#  'una_campo',
#  'campo_moraes',
#  'moraes_vera',
#  'vera_poucos',
#  'poucos_mente',
#  'mente_lar',
#  'lar_cora',
#  'cora_existente',
#  'existente_descido',
#  'descido_feridos',
#  'feridos_toda',
#  'toda_eo',
#  'eo_fiar',
#  'fiar_pessoa',
#  'pessoa_setembro',
#  'setembro_sul',
#  'sul_ponta',
#  'ponta_conveniente',
#  'conveniente_chegou',
#  'chegou_quanto',
#  'quanto_forte',
#  'forte_primeiros',
#  'primeiros_assucar',
#  'assucar_pedro',
#  'pedro_dias',
#  'dias_pessoal',
#  'pessoal_general',
#  'general_coutinho',
#  'coutinho_escrever',
#  'escrever_alberto',
#  'alberto_julgar',
#  'julgar_seguir',
#  'seguir_seguintes',
#  'seguintes_forcas',
#  'forcas_cerca',
#  'cerca_fazer',
#  'fazer_frente',
#  'frente_parati',
#  'parati_amigo',
#  'amigo_bem',
#  'bem_pesadas',
#  'pesadas_rofo',
#  'rofo_bateria',
#  'bateria_caso',
#  'caso_tudo',
#  'tudo_quo',
#  't_negociante',
#  'negociante_ricos',
#  'ia_ju',
#  'fundada_avenida',
#  'avenida_casa',
#  'casa_ic',
#  'fundada_ot',
#  'ot_b',
#  'b_avenida',
#  'avenida_casa',
#  'fundada_avenida',
#  'avenida_casa',
#  'afinal_caro',
#  'caro_rito',
#  'rito_outro',
#  'outro_tio',
#  'tio_tanto',
#  'tanto_toner',
#  'toner_t',
#  't_uri',
#  'uri_tao',
#  'tao_w',
#  'w_poder',
#  'poder_ingrata',
#  'ingrata_ja',
#  'ja_ignorar',
#  'ignorar_ido',
#  'ido_ora',
#  'ora_v',
#  'v_nada',
#  'nada_major',
#  'major_taca',
#  'taca_p',
#  'p_uns',
#  'uns_sabia',
#  'sabia_i',
#  'i_pouco',
#  'pouco_alii',
#  'alii_isidoro',
#  'isidoro_dia',
#  'dia_caso',
#  'caso_u',
#  'u_tudo',
#  'tudo_verno',
#  'verno_cem',
#  'cem_adido',
#  'adido_carta',
#  'carta_desejava',
#  'desejava_quo',
#  'quo_m',
#  'muitos_conta',
#  'conta_coisa',
#  'coisa_eis',
#  'eis_assis',
#  'assis_arma',
#  'arma_palavra',
#  'palavra_apoio',
#  'apoio_prestigio',
#  'prestigio_nada',
#  'nada_deve',
#  'deve_aquem',
#  'aquem_duvidar',
#  'duvidar_magoar',
#  'magoar_ponderada',
#  'ponderada_escorar',
#  'escorar_preciso',
#  'preciso_melhor',
#  'melhor_ate',
#  'ate_brasil',
#  'brasil_dever',
#  'dever_ponto',
#  'ponto_leal',
#  'leal_tocar',
#  'tocar_certo',
#  'certo_caro',
#  'caro_senhor',
#  'senhor_sabe',
#  'sabe_todo',
#  'todo_esclarecido',
#  'esclarecido_aqui',
#  'aqui_fim',
#  'fim_junta',
#  'junta_escolha',
#  'escolha_ia',
#  'ia_acolhida',
#  'acolhida_honra',
#  'honra_pessimista',
#  'pessimista_infame',
#  'infame_amigos',
#  'amigos_proveito',
#  'proveito_defeito',
#  'defeito_carta',
#  'carta_poderia',
#  'poderia_homens',
#  'homens_honesto',
#  'honesto_publicada',
#  'publicada_coronel',
#  'coronel_tanto',
#  'tanto_terra',
#  'terra_convite',
#  'convite_honestidade',
#  'honestidade_enviado',
#  'enviado_favor',
#  'favor_mesquita',
#  'mesquita_digo',
#  'digo_resolvido',
#  'resolvido_s',
#  's_grave',
#  'grave_meios',
#  'meios_mim',
#  'mim_receber',
#  'receber_posso',
#  'posso_br',
#  'br_feita',
#  'feita_dia',
#  'dia_interesse',
#  'interesse_franqueza',
#  'franqueza_tirar',
#  'tirar_inteligente',
#  'inteligente_primeiro',
#  'primeiro_algum',
#  'algum_ser',
#  'ser_quanto',
#  'quanto_apoiado',
#  'apoiado_ouvir',
#  'ouvir_ponderado',
#  'ponderado_inda',
#  'inda_outro',
#  'outro_chefe',
#  'chefe_partido',
#  'partido_terceiro',
#  'terceiro_julgar-se',
#  'julgar-se_civis',
#  'civis_dar',
#  'dar_vingado',
#  'vingado_aprovar',
#  'aprovar_ja',
#  'ja_pessoal',
#  'pessoal_afirmar',
#  'afirmar_porque',
#  'porque_ambos',
#  'ambos_motivo',
#  'motivo_fazer',
#  'fazer_sendo',
#  'sendo_f',
#  'f_cumprir',
#  'cumprir_facto',
#  'facto_amigo',
#  'amigo_algo',
#  'algo_caso',
#  'caso_tudo',
#  'tudo_franco',
#  'franco_ideia',
#  'ideia_boletim',
#  'boletim_chegar',
#  'chegar_estudar',
#  'estudar_conhecer',
#  'quanto_pensar',
#  'pensar_apagar',
#  'apagar_fevereiro',
#  'fevereiro_servir',
#  'servir_santa',
#  'santa_afixar',
#  'afixar_imposta',
#  'imposta_ja',
#  'ja_natureza',
#  'natureza_grande',
#  'grande_claro',
#  'claro_s',
#  's_rei',
#  'rei_preciso',
#  'preciso_rocha',
#  'rocha_movimento',
#  'movimento_pudor',
#  'pudor_cio',
#  'cio_enviar',
#  'enviar_posso',
#  'posso_dessa',
#  'dessa_perigo',
#  'perigo_u',
#  'u_tudo',
#  'tudo_sul',
#  'sul_quo',
#  'quo_plantado',
#  'ja_d',
#  'up_p',
#  'c_oc',
#  'oc_ja',
#  'ja_z',
#  'z_sp',
#  'ov_oca',
#  'oca_casaca',
#  'd_y',
#  'ov_ah',
#  'ah_max',
#  'max_xa',
#  'xa_iu',
#  'iu_ih',
#  'v_x',
#  'x_ja',
#  'ja_fu',
#  'muitos_escrutinio',
#  'escrutinio_algumas',
#  'algumas_objectivo',
#  'objectivo_iniciado',
#  'iniciado_armas',
#  'armas_industria',
#  'industria_tirados',
#  'tirados_consoante',
#  'consoante_afim',
#  'afim_obrigado',
#  'obrigado_patriotismo',
#  'patriotismo_menos',
#  'menos_nada',
#  'nada_deve',
#  'deve_verdadeiros',
#  'verdadeiros_cep',
#  'cep_reis',
#  'reis_brasil',
#  'brasil_patricio',
#  'patricio_outras',
#  'outras_lei',
#  'lei_sagrados',
#  'sagrados_progresso',
#  'progresso_vaga',
#  'vaga_sabe',
#  'sabe_convidado',
#  'convidado_carestia',
#  'carestia_presidente',
#  'presidente_talvez',
#  'talvez_promessa',
#  'promessa_xis',
#  'xis_designados',
#  'designados_aqui',
#  'aqui_contra',
#  'contra_passo',
#  'passo_uniforme',
#  'uniforme_ido',
#  'ido_armado',
#  'armado_artificial',
#  'artificial_divida',
#  'divida_agentes',
#  'agentes_capaz',
#  'capaz_economicamente',
#  'economicamente_movimento',
#  'movimento_poderes',
#  'poderes_urgentes',
#  'urgentes_cem',
#  'cem_apresentar',
#  'apresentar_vinte',
#  'vinte_guerra',
#  'guerra_riqueza',
#  'riqueza_presidentes',
#  'presidentes_feroz',
#  'feroz_pais',
#  'pais_menor',
#  'menor_erradamente',
#  'erradamente_ordem',
#  'ordem_sentir',
#  'sentir_trocar',
#  'trocar_relativas',
#  'relativas_contrario',
#  'contrario_formula',
#  'formula_cessar',
#  'cessar_elevados',
#  'elevados_gostosamente',
#  'gostosamente_pratica',
#  'pratica_despeito',
#  'despeito_lado',
#  'lado_pois',
#  'pois_geral',
#  'geral_todos',
#  'todos_algum',
#  'algum_filhos',
#  'filhos_revelia',
#  'revelia_artigo',
#  'artigo_outro',
#  'outro_terceiro',
#  'terceiro_remediadas',
#  'remediadas_delegado',
#  'delegado_politicamente',
#  'politicamente_dar',
#  'dar_estado',
#  'estado_vi',
#  'vi_fecha',
#  'fecha_pagar',
#  'pagar_ensino',
#  'ensino_pobres',
#  'pobres_marcha',
#  'marcha_termos',
#  'termos_governo',
#  'governo_voto',
#  'voto_beneficio',
#  'beneficio_possibilidade',
#  'possibilidade_fazer',
#  'fazer_mesma',
#  'mesma_facto',
#  'facto_tudo',
#  'vaga_embora',
#  'embora_pensar',
#  'pensar_publica',
#  'publica_armar',
#  'armar_cambulhada',
#  'cambulhada_pensa',
#  'pensa_preciosa',
#  'preciosa_terra',
#  'terra_aniquilados',
#  'aniquilados_profundo',
#  'profundo_rara',
#  'rara_poder',
#  'poder_pureza',
#  'pureza_criminosos',
#  'criminosos_dias',
#  'dias_mil',
#  'mil_vencedora',
#  'vencedora_garantidos',
#  'garantidos_ora',
#  'ora_velha',
#  'velha_vencidos',
#  'vencidos_claro',
#  'claro_obstante',
#  'obstante_nome',
#  'nome_dignos',
#  'dignos_honra',
#  'honra_amizade',
#  'amizade_crimes',
#  'crimes_pegar',
#  'pegar_entrar',
#  'entrar_brasil',
#  'brasil_insigne',
#  'insigne_despeito',
#  'despeito_crentes',
#  'crentes_objectivos',
#  'objectivos_obter',
#  'obter_dentro',
#  'dentro_lopes',
#  'esquecimento_quanto',
#  'quanto_animado',
#  'animado_propriedades',
#  'propriedades_publica',
#  'publica_federal',
#  'federal_outro',
#  'outro_vista',
#  'vista_compatriota',
#  'compatriota_medidas',
#  'medidas_compromisso',
#  'compromisso_liberdades',
#  'liberdades_vida',
#  'vida_faz',
#  'faz_civis',
#  'civis_envolvidos',
#  'envolvidos_apoderado',
#  'apoderado_estado',
#  'estado_maia',
#  'maia_sentimentos',
#  'sentimentos_fiel',
#  'fiel_cidade',
#  'cidade_mesmos',
#  'mesmos_sincera',
#  'sincera_ordem',
#  'ordem_governo',
#  'governo_grande',
#  'grande_congresso',
#  'congresso_altos',
#  'altos_familia',
#  'familia_directa',
#  'directa_rio',
#  'rio_material',
#  'material_dia',
#  'dia_laboriosa',
#  'laboriosa_sul',
#  'sul_desenvolvimento',
#  'desenvolvimento_inspirados',
#  'inspirados_constitucional',
#  'constitucional_brasileira',
#  'atenta_sucursal',
#  'sucursal_santa',
#  'santa_fecha',
#  'fecha_jorge',
#  'jorge_comunicado',
#  'comunicado_general',
#  'general_miguel',
#  'miguel_s',
#  's_trasladado',
#  'trasladado_motivo',
#  'motivo_don',
#  'don_trasladar',
#  'trasladar_distinguida',
#  'distinguida_uno',
#  'uno_loa',
#  'loa_sub',
#  'sub_nota',
#  'nota_cada',
#  'cada_corte',
#  'corte_costa',
#  'costa_atento',
#  'ej_brasil',
#  'brasil_s',
#  'r_gabinete',
#  'y_gabinete',
#  'je_l',
#  'estrada_ferro',
#  'vs_fr',
#  'documento_consulta',
#  'consulta_todavia',
#  'documento_consulta',
#  'consulta_todavia',
#  'ser_tempo',
#  'tempo_resistir',
#  'resistir_restabelecimento',
#  'restabelecimento_retirada',
#  'retirada_afim',
#  'afim_pessoal',
#  'pessoal_grossa',
#  'grossa_passagem',
#  'passagem_rio',
#  'rio_nenhum',
#  'nenhum_descuidado',
#  'descuidado_outros',
#  'outros_invadir',
#  'invadir_item',
#  'item_primeiro',
#  'mandado_rompido',
#  'rompido_cerco',
#  'cerco_completa',
#  'completa_prestes',
#  'prestes_maia',
#  'maia_ja',
#  'ja_mil',
#  'mil_marcha',
#  'marcha_miguel',
#  'miguel_nada',
#  'nada_fazer',
#  'fazer_honra',
#  'honra_sendo',
#  'sendo_amizade',
#  'amizade_uns',
#  'uns_pouco',
#  'pouco_ultimo',
#  'ultimo_tomar',
#  'tomar_liberdade',
#  'liberdade_poderosas',
#  'poderosas_posso',
#  'posso_rolante',
#  'rolante_ala',
#  'ala_gloria',
#  'gloria_maior',
#  'maior_exigir',
#  'exigir_sul',
#  'sul_abril',
#  'abril_numero',
#  'y_ed',
#  'podar_chefe',
#  'chefe_interrompidas',
#  'interrompidas_mendes',
#  'mendes_retirar',
#  'retirar_copia',
#  'copia_hora',
#  'hora_reparar',
#  'reparar_estado',
#  'estado_providencia',
#  'providencia_porto',
#  'porto_teixeira',
#  'teixeira_ordem',
#  'ordem_general',
#  'general_providenciar',
#  'providenciar_restabelecer',
#  'restabelecer_mono',
#  'mono_quer',
#  'quer_bel',
#  'bel_empregar',
#  'empregar_padilha',
#  'padilha_maior',
#  'maior_abril',
#  'abril_provisoriamente',
#  'vapor_continuar',
#  'continuar_momento',
#  'momento_poder',
#  'poder_suficiente',
#  'suficiente_motor',
#  'motor_zona',
#  'zona_una',
#  'una_empresa',
#  'empresa_lancha',
#  'lancha_ia',
#  'ia_max',
#  'max_chata',
#  'chata_deficientes',
#  'deficientes_aceite',
#  'aceite_ud',
#  'ud_ala',
#  'ala_dia',
#  'dia_presente',
#  'presente_abril',
#  'abril_carta',
#  'carta_apenas',
#  'apenas_portador',
#  'c_f',
#  'f_j',
#  'j_ju',
#  'ju_t',
#  'etc_z',
#  ...]

# %%
len(total_unigramas)
# Out:
# 485688
